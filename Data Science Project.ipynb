# %%
import pandas as pd
import numpy as np

df = pd.read_csv('world_population.csv')

# %% [markdown]
# - I imported the pandas as pd here so I can use the library for my code
# - I also imported the numpy as np here as well because I wanted to use the library from it as well for my code
# - I got the DataFrame as df and told it to read the csv file that I found for my dataset

# %%
del df['Capital']

# %%
del df['2000 Population']

# %%
del df['2010 Population']

# %% [markdown]
# - I altered the dataset by taking out 3 categories because they did not have significance towards the part of the data that I was interested in

# %%
df.head()
# Out:
#    Rank CCA3         Country Continent  2022 Population  2020 Population  \
# 0    36  AFG     Afghanistan      Asia         41128771         38972230
# 1   138  ALB         Albania    Europe          2842321          2866849
# 2    34  DZA         Algeria    Africa         44903225         43451666
# 3   213  ASM  American Samoa   Oceania            44273            46189
# 4   203  AND         Andorra    Europe            79824            77700
#
#    2015 Population  1990 Population  1980 Population  1970 Population  \
# 0         33753499         10694796         12486631         10752971
# 1          2882481          3295066          2941651          2324731
# 2         39543154         25518074         18739378         13795915
# 3            51368            47818            32886            27075
# 4            71746            53569            35611            19860
#
#    Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0      652230            63.0587       1.0257                         0.52
# 1       28748            98.8702       0.9957                         0.04
# 2     2381741            18.8531       1.0164                         0.56
# 3         199           222.4774       0.9831                         0.00
# 4         468           170.5641       1.0100                         0.00

# %% [markdown]
# - I looked at the data as a whole after I altered the dataset

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - I imported this matplotlib.pyplot as plt so that I could create a bar graph from it

# %%
data = {'1970 Population': 52019, '2022 Population': 64184}
Years = list(data.keys())
Population = list(data.values())

# %% [markdown]
# - Here is where I inserted the data that I had for comparing different timelines of populations for the country Bermuda
# - I made a keys and values list so that the years would correspond as the 'X' axis and the Population would correspond as the 'Y' axis

# %%
plt.bar(Years, Population, color ='blue',
        width = 0.4)
plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Bermuda Population Comparison")
plt.show()

# %% [markdown]
# - I created the bar graph here and I inserted the width of how far apart I would like my comparisons to be
# - I labeled the 'X' and 'Y' axis according to the Years and Population
# - I added in a title that would make sense for the Comparision of Years
# - I wrote out that I would like to show this bar graph and see the output

# %%
df.to_csv()
# Out:
# ',Rank,CCA3,Country,Continent,2022 Population,2020 Population,2015 Population,1990 Population,1980 Population,1970 Population,Area (km²),Density (per km²),Growth Rate,World Population Percentage\n0,36,AFG,Afghanistan,Asia,41128771,38972230,33753499,10694796,12486631,10752971,652230,63.0587,1.0257,0.52\n1,138,ALB,Albania,Europe,2842321,2866849,2882481,3295066,2941651,2324731,28748,98.8702,0.9957,0.04\n2,34,DZA,Algeria,Africa,44903225,43451666,39543154,25518074,18739378,13795915,2381741,18.8531,1.0164,0.56\n3,213,ASM,American Samoa,Oceania,44273,46189,51368,47818,32886,27075,199,222.4774,0.9831,0.0\n4,203,AND,Andorra,Europe,79824,77700,71746,53569,35611,19860,468,170.5641,1.01,0.0\n5,42,AGO,Angola,Africa,35588987,33428485,28127721,11828638,8330047,6029700,1246700,28.5466,1.0315,0.45\n6,224,AIA,Anguilla,North America,15857,15585,14525,8316,6560,6283,91,174.2527,1.0066,0.0\n7,201,ATG,Antigua and Barbuda,North America,93763,92664,89941,63328,64888,64516,442,212.1335,1.0058,0.0\n8,33,ARG,Argentina,South America,45510318,45036032,43257065,32637657,28024803,23842803,2780400,16.3683,1.0052,0.57\n9,140,ARM,Armenia,Asia,2780469,2805608,2878595,3556539,3135123,2534377,29743